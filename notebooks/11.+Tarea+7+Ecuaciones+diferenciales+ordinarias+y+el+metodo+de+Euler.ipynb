# %% [markdown]
# # Ecuaciones diferenciales ordinarias

# %% [markdown]
# Recordemos qué una **ecuación diferencial ordinaria (EDO)** es (aproximadamente) una ecuación en la cual aparece una derivada de una función, y para la cual queremos buscar la solución para esta función.
#
# La EDO más simple no-trivial y físicamente relevante en una variable es
#
# $$\dot{x} = -\alpha x.$$
#
# [Recordemos la notación $\dot{x} := \textstyle \frac{dx}{dt}$, donde $t$ es el tiempo; es muy común en la física que las EDOs involucren derivadas con respecto al tiempo.]

# %% [markdown]
# Una solución a esta ecuación es un objeto $x$, tal que cuando la derivamos con respecto al tiempo, nos da $-\alpha$ (una constante) multiplicada por el mismo objeto. Implícitamente está claro que $x$ depende de $t$, por lo que realmente $x$ se refiere a una función de $t$, es decir $x: \mathbb{R} \to \mathbb{R}$, con $x: t \mapsto x(t)$. Esta ecuación se puede considerar como ecuación *funcional*, es decir, una igualdad de funciones, y se puede escribir más explícitamente como sigue:
#
# $$\dot{x}(t) = -\alpha x(t) \qquad \text{para cada } t \in [0, \infty).$$
#
# En mi opinión, en esta forma queda más claro.
#
# Esto quiere decir que si *de alguna manera* hayamos logrado saber que la solución en el tiempo $t$ está en la posición $x(t)$, entonces nos indica cuál será la *velocidad* $\dot{x}(t)$ en este momento.

# %% [markdown]
# La forma general de una EDO en una variable es
#
# $$\dot{x} = f(x, t),$$
#
# o sea
#
# $$\dot{x}(t) = f(x(t), t) \qquad \text{para cada } t.$$
#
# Recordemos que **debe ir acompañada por una condición inicial $x(t=t_0) = x_0$** para que constituya un problema bien planteado (*problema de valores iniciales*, o *problema de Cauchy*).
#
# Bajo ciertas condiciones técnicas, se puede demostrar que la combinación de la ecuación diferencial junto con la condición inicial tenga una solución, y que esta solución es única.
# La solución es *función* $x(t)$ que satisface al mismo tiempo que $\dot{x}(t) = f(x(t), t)$ para cada $t$, y que $x(t=t_0) = x_0$.
#
# En el caso particular de la ecuación $\dot{x} = -\alpha x$, conocemos analíticamente la solución, y nos servirá para comprobar nuestros métodos. Pero para las ecuaciones de interés para la física, esto *casi nunca ocurre*, una situación que ¡suele pasar desapercibida durante la carrera! En estos casos, debemos aplicar distintas técnicas de *aproximación* de la solución, entre las cuales se destacan los *métodos numéricos*.

# %% [markdown]
# # Método de Euler

# %% [markdown]
# Para resolver una EDO numéricamente en la computadora, tendremos que *aproximar* la solución continua $x: t \mapsto x(t)$ con una versión con una cantidad finita de información, es decir, *discretizarla* de alguna forma.
#
# La manera más sencilla de hacerla es usando *diferencias finitas*.

# %% [markdown]
# **[1]** (i) ¿Cuál es la *aproximación* más sencilla de la derivada $\dot{x}(t)$, en términos de un tamaño de paso pequeño $h$? (¿Por qué sólo es una aproximación?)
#
# (ii) Aplica esta aproximación con la ecuación $\dot{x} = f(x, t)$ para obtener una expresión para $x(t+h)$, es decir el valor *predicho* en el siguiente *paso* de tiempo, en términos del valor ya conocido $x(t)$.
#
# (iii) Implementa este *método de Euler* en una función. Para hacerlo, crea un arreglo `ts` de los tiempos en los cuales se evaluará la función. Luego crea otro arreglo de ceros, con la función `zeros`. [Si pasas el arreglo `t` como argumento a esta función, creará un arreglo del mismo tamaño automáticamente.] Ahora implementa el paso (ii) en un algoritmo iterativo para actualizar los valores en el nuevo arreglo para cada tiempo sucesivamente.
#
# (iv) Verifica que funcione tu método al aplicarlo a una función $f(t)$ sencilla que dependa *únicamente del tiempo*. [Recuerda que debes imponer una condición inicial.] ¿Cuál operación matemática acabas de llevar a cabo? Compara con la solución analítica.

# %% [markdown]
# [1] (i, ii)
# Recordemos la definición de derivada, esto es
# $$
# \dfrac{dx}{dt} = \lim _{h\to0} \dfrac{x(t+h)-x(t)}{h}
# $$
# Por lo que una aproximación es
# $$
# \dot{x} \approx \dfrac{x(t+h) - x(t)}{h}
# $$
# Para $h$ pequeña.

# %%
using Plots
using Interact
gr()
# Out:
# <div id="interact-js-shim">
#     <script charset="utf-8">
# (function (IPython, $, _, MathJax) {
#     $.event.special.destroyed = {
# 	remove: function(o) {
# 	    if (o.handler) {
# 		o.handler.apply(this, arguments)
# 	    }
# 	}
#     }
#
#     var OutputArea = IPython.version >= "4.0.0" ? require("notebook/js/outputarea").OutputArea : IPython.OutputArea;
#
#     var redrawValue = function (container, type, val) {
# 	var selector = $("<div/>");
# 	var oa = new OutputArea(_.extend(selector, {
# 	    selector: selector,
# 	    prompt_area: true,
# 	    events: IPython.events,
# 	    keyboard_manager: IPython.keyboard_manager
# 	})); // Hack to work with IPython 2.1.0
#
# 	switch (type) {
# 	case "image/png":
#             var _src = 'data:' + type + ';base64,' + val;
# 	    $(container).find("img").attr('src', _src);
# 	    break;
# 	case "text/latex":
# 		if (MathJax){
# 			var math = MathJax.Hub.getAllJax(container)[0];
# 			MathJax.Hub.Queue(["Text", math, val.replace(/^\${1,2}|\${1,2}$/g, '')]);
# 			break;
# 		}
# 	default:
# 	    var toinsert = OutputArea.append_map[type].apply(
# 		oa, [val, {}, selector]
# 	    );
# 	    $(container).empty().append(toinsert.contents());
# 	    selector.remove();
# 	}
#     }
#
#
#     $(document).ready(function() {
# 	function initComm(evt, data) {
# 	    var comm_manager = data.kernel.comm_manager;
#         //_.extend(comm_manager.targets, require("widgets/js/widget"))
# 	    comm_manager.register_target("Signal", function (comm) {
#             comm.on_msg(function (msg) {
#                 var val = msg.content.data.value;
#                 $(".signal-" + comm.comm_id).each(function() {
#                 var type = $(this).data("type");
#                 if (typeof(val[type]) !== "undefined" && val[type] !== null) {
#                     redrawValue(this, type, val[type], type);
#                 }
#                 });
#                 delete val;
#                 delete msg.content.data.value;
#             });
# 	    });
#
# 	    // coordingate with Comm and redraw Signals
# 	    // XXX: Test using Reactive here to improve performance
# 	    $([IPython.events]).on(
# 		'output_appended.OutputArea', function (event, type, value, md, toinsert) {
# 		    if (md && md.reactive) {
#                 // console.log(md.comm_id);
#                 toinsert.addClass("signal-" + md.comm_id);
#                 toinsert.data("type", type);
#                 // Signal back indicating the mimetype required
#                 var comm_manager = IPython.notebook.kernel.comm_manager;
#                 var comm = comm_manager.comms[md.comm_id];
#                 comm.then(function (c) {
#                     c.send({action: "subscribe_mime",
#                        mime: type});
#                     toinsert.bind("destroyed", function() {
#                         c.send({action: "unsubscribe_mime",
#                                mime: type});
#                     });
#                 })
# 		    }
# 	    });
# 	}
#
# 	try {
# 	    // try to initialize right away. otherwise, wait on the status_started event.
# 	    initComm(undefined, IPython.notebook);
# 	} catch (e) {
# 	    $([IPython.events]).on('kernel_created.Kernel kernel_created.Session', initComm);
# 	}
#     });
# })(IPython, jQuery, _, MathJax);
# </script>
#     <script>
#         window.interactLoadedFlag = true
#        $("#interact-js-shim").bind("destroyed", function () {
#            if (window.interactLoadedFlag) {
#                console.warn("JavaScript required by Interact will be removed if you remove this cell or run using Interact more than once.")
#            }
#        })
#        $([IPython.events]).on("kernel_starting.Kernel kernel_restarting.Kernel", function () { window.interactLoadedFlag = false })
#    </script>
# </div>
# Plots.GRBackend()

# %%
# [1] (iii)
function euler(f, h, t0, x0)
    ts = t0:h:10
    x = zeros(ts)
    x[1] = x0
    for i in 1:length(ts)-1
        x[i+1] = (h * f(x[i], ts[i])) + x[i]
    end
    return ts, x
end
# Out:
# euler (generic function with 1 method)

# %%
# [1] (iV)
g(x, t) = cos(t)
t0 = 0
x0 = 0
t, x = euler(g, 0.001, t0, x0)
# Out:
# (0.0:0.001:10.0, [0.0, 0.001, 0.002, 0.003, 0.00399999, 0.00499999, 0.00599997, 0.00699995, 0.00799993, 0.0089999  …  -0.535526, -0.536369, -0.537213, -0.538056, -0.538898, -0.53974, -0.540581, -0.541422, -0.542262, -0.543102])

# %%
plot(t, x, xlabel = "Tiempo", label="Numérico")
plot!(t, sin, label="Analítico")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,372.441 592.126,372.441 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="366"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.3701,366.972 39.3701,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.921,366.972 149.921,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   260.472,366.972 260.472,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.024,366.972 371.024,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   481.575,366.972 481.575,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,366.972 592.126,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,281.322 583.835,281.322
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,190.203 583.835,190.203
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,99.0841 583.835,99.0841
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,7.96513 583.835,7.96513
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 592.126,372.441
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 39.3701,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.921,372.441 149.921,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   260.472,372.441 260.472,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.024,372.441 371.024,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   481.575,372.441 481.575,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,372.441 592.126,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,281.322 47.6614,281.322
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,190.203 47.6614,190.203
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,99.0841 47.6614,99.0841
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.96513 47.6614,7.96513
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 386.241)" x="39.3701" y="386.241">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.921, 386.241)" x="149.921" y="386.241">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.472, 386.241)" x="260.472" y="386.241">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.024, 386.241)" x="371.024" y="386.241">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 481.575, 386.241)" x="481.575" y="386.241">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 386.241)" x="592.126" y="386.241">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 285.822)" x="33.3701" y="285.822">-0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 194.703)" x="33.3701" y="194.703">0.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 103.584)" x="33.3701" y="103.584">0.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 12.4651)" x="33.3701" y="12.4651">1.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.748, 397.6)" x="315.748" y="397.6">Tiempo</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,190.203 39.4254,190.021 39.4806,189.839 39.5359,189.656 39.5912,189.474 39.6465,189.292 39.7017,189.11 39.757,188.927 39.8123,188.745 39.8676,188.563
#   39.9228,188.381 39.9781,188.198 40.0334,188.016 40.0887,187.834 40.1439,187.652 40.1992,187.47 40.2545,187.287 40.3098,187.105 40.365,186.923 40.4203,186.741
#   40.4756,186.559 40.5309,186.376 40.5861,186.194 40.6414,186.012 40.6967,185.83 40.752,185.648 40.8072,185.465 40.8625,185.283 40.9178,185.101 40.9731,184.919
#   41.0283,184.737 41.0836,184.555 41.1389,184.372 41.1942,184.19 41.2494,184.008 41.3047,183.826 41.36,183.644 41.4153,183.462 41.4706,183.28 41.5258,183.098
#   41.5811,182.915 41.6364,182.733 41.6917,182.551 41.7469,182.369 41.8022,182.187 41.8575,182.005 41.9128,181.823 41.968,181.641 42.0233,181.459 42.0786,181.277
#   42.1339,181.095 42.1891,180.913 42.2444,180.731 42.2997,180.549 42.355,180.367 42.4102,180.185 42.4655,180.003 42.5208,179.821 42.5761,179.639 42.6313,179.457
#   42.6866,179.275 42.7419,179.093 42.7972,178.911 42.8524,178.729 42.9077,178.548 42.963,178.366 43.0183,178.184 43.0735,178.002 43.1288,177.82

# %% [markdown]
# **[2]** (i) Utiliza tu función para resolver la ecuación $\dot{x} = -\alpha x$ con la condición inicial $x(t=0) = 1$, y compara tu solución numérica gráficamente con la solución analítica de la ecuación. ¿Qué pasa al variar el paso de tiempo? Hazlo interactivo.
#
# (ii) Dado que el método de Euler utiliza una aproximación, el resultado no es exacto. Fija una $t$ final y calcula el error (desde la solución analítica) en función del tamaño de paso $h$. ¿Cómo es la tasa de convergencia en función de $h$?

# %%
# [2] (i)
t0 = 0
x0 = 1
α = 1
h = 0.01
t, x = euler((x,t) -> -α*x, h, t0, x0)
plot(t, x, label="Numérico", xlabel="Tiempo")
plot!(x -> exp(-α*x), label="Analítico")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,372.441 592.126,372.441 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="366"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.3701,366.972 39.3701,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.921,366.972 149.921,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   260.472,366.972 260.472,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.024,366.972 371.024,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   481.575,366.972 481.575,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,366.972 592.126,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,281.311 583.835,281.311
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,190.165 583.835,190.165
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,99.0197 583.835,99.0197
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,7.87402 583.835,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 592.126,372.441
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 39.3701,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.921,372.441 149.921,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   260.472,372.441 260.472,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.024,372.441 371.024,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   481.575,372.441 481.575,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,372.441 592.126,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,281.311 47.6614,281.311
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,190.165 47.6614,190.165
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,99.0197 47.6614,99.0197
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.87402 47.6614,7.87402
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 386.241)" x="39.3701" y="386.241">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.921, 386.241)" x="149.921" y="386.241">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.472, 386.241)" x="260.472" y="386.241">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.024, 386.241)" x="371.024" y="386.241">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 481.575, 386.241)" x="481.575" y="386.241">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 386.241)" x="592.126" y="386.241">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 285.811)" x="33.3701" y="285.811">0.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 194.665)" x="33.3701" y="194.665">0.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 103.52)" x="33.3701" y="103.52">0.75</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 12.374)" x="33.3701" y="12.374">1.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.748, 397.6)" x="315.748" y="397.6">Tiempo</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.87402 39.9228,11.5198 40.4756,15.1292 41.0283,18.7025 41.5811,22.24 42.1339,25.7422 42.6866,29.2093 43.2394,32.6418 43.7921,36.04 44.3449,39.4041
#   44.8976,42.7347 45.4504,46.0319 46.0031,49.2961 46.5559,52.5277 47.1087,55.727 47.6614,58.8943 48.2142,62.0299 48.7669,65.1342 49.3197,68.2074 49.8724,71.2499
#   50.4252,74.262 50.978,77.2439 51.5307,80.1961 52.0835,83.1187 52.6362,86.0121 53.189,88.8765 53.7417,91.7123 54.2945,94.5197 54.8472,97.2991 55.4,100.051
#   55.9528,102.775 56.5055,105.472 57.0583,108.141 57.611,110.785 58.1638,113.401 58.7165,115.992 59.2693,118.556 59.822,121.095 60.3748,123.609 60.9276,126.098
#   61.4803,128.561 62.0331,131 62.5858,133.415 63.1386,135.805 63.6913,138.172 64.2441,140.514 64.7969,142.834 65.3496,145.13 65.9024,147.403 66.4551,149.654
#   67.0079,151.882 67.5606,154.088 68.1134,156.271 68.6661,158.433 69.2189,160.573 69.7717,162.692 70.3244,164.79 70.8772,166.867 71.4299,168.923 71.9827,170.958
#   72.5354,172.973 73.0882,174.968 73.6409,176.943 74.1937,178.898 74.7465,180.833 75.2992,182.75 75.852,184.647 76.4047,186.525 76.9575,188.384 77.5102

# %%
# [2] (ii)
t0 = 0
x0 = 1
α = 1
solucion(x) = exp(-α * x)
@manipulate for h = 0.1:0.1:5
    t, x = euler((x,t) -> -α*x, h, t0, x0)
    t_fija = t[end - 1]
    dif = abs(x[end - 1] - solucion(t_fija))
end
# Out:
# Interact.Options{:SelectionSlider,Float64}(13: "input-5" = 2.5 Float64 , "h", 2.5, "2.5", Interact.OptionDict(DataStructures.OrderedDict("0.1"=>0.1,"0.2"=>0.2,"0.3"=>0.3,"0.4"=>0.4,"0.5"=>0.5,"0.6"=>0.6,"0.7"=>0.7,"0.8"=>0.8,"0.9"=>0.9,"1.0"=>1.0…), Dict(1.2=>"1.2",4.3=>"4.3",2.0=>"2.0",1.5=>"1.5",1.4=>"1.4",0.2=>"0.2",3.5=>"3.5",4.9=>"4.9",0.3=>"0.3",2.2=>"2.2"…)), Any[], Any[], true, "horizontal")
# 3.375553084370148

# %% [markdown]
# **[3]** Considera la ecuación diferencial nolineal $\dot{x} = x \,(1-x)$ que modela la dinámica de una población. Resúelvela numéricamente desde distintas condiciones iniciales (que sean físicamente relevantes) y dibuja las soluciones correspondientes. Interpreta el resultado.

# %%
f(x,t) = x*(1 - x)
t0 = 1
f0 = 1
h = .2
t, x = euler(f, h, t0, f0)
plot(t, x)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   131.496,370.85 131.496,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   285.039,370.85 285.039,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   438.583,370.85 438.583,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,370.85 592.126,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,376.378 583.835,376.378
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,284.252 583.835,284.252
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,192.126 583.835,192.126
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,100 583.835,100
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,7.87402 583.835,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 592.126,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   131.496,376.378 131.496,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   285.039,376.378 285.039,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   438.583,376.378 438.583,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,376.378 592.126,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 47.6614,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,284.252 47.6614,284.252
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,192.126 47.6614,192.126
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,100 47.6614,100
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.87402 47.6614,7.87402
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 131.496, 390.178)" x="131.496" y="390.178">2.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 285.039, 390.178)" x="285.039" y="390.178">5.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 438.583, 390.178)" x="438.583" y="390.178">7.5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 390.178)" x="592.126" y="390.178">10.0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 380.878)" x="33.3701" y="380.878">1.00</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 288.752)" x="33.3701" y="288.752">1.25</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 196.626)" x="33.3701" y="196.626">1.50</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 104.5)" x="33.3701" y="104.5">1.75</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 12.374)" x="33.3701" y="12.374">2.00</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 51.6535,376.378 63.937,376.378 76.2205,376.378 88.5039,376.378 100.787,376.378 113.071,376.378 125.354,376.378 137.638,376.378 149.921,376.378
#   162.205,376.378 174.488,376.378 186.772,376.378 199.055,376.378 211.339,376.378 223.622,376.378 235.906,376.378 248.189,376.378 260.472,376.378 272.756,376.378
#   285.039,376.378 297.323,376.378 309.606,376.378 321.89,376.378 334.173,376.378 346.457,376.378 358.74,376.378 371.024,376.378 383.307,376.378 395.591,376.378
#   407.874,376.378 420.157,376.378 432.441,376.378 444.724,376.378 457.008,376.378 469.291,376.378 481.575,376.378 493.858,376.378 506.142,376.378 518.425,376.378
#   530.709,376.378 542.992,376.378 555.276,376.378 567.559,376.378 579.843,376.378 592.126,376.378
#   "/>
# <polygon clip-path="url(#clip00)" points="
# 501.61,58.994 574.126,58.994 574.126,28.754 501.61,28.754
#   " fill="#ffffff" fill-opacity="1"/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   501.61,58.994 574.126,58.994 574.126,28.754 501.61,28.754 501.61,58.994
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   507.61,43.874 543.61,43.874
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:start;" transform="rotate(0, 549.61, 48.374)" x="549.61" y="48.374">y1</text>
# </g>
# </svg>

# %% [markdown]
# # Varias variables

# %% [markdown]
# El método de Euler se extiende directamente a EDOs con más de una variable.

# %% [markdown]
# **[4]** (i) Deriva un método de Euler para las ecuaciones acopladas
# $$\dot{x} = f(x, y);$$
# $$\dot{y} = g(x, y).$$
#
# Para hacerlo, aplica la definición de las derivadas de nuevo.
#
# (ii) Implementa el método.
#
# (iii) Aplícalo a la ecuación diferencial lineal que describe un oscilador armónico amortiguado. [Pista: Recuerda que para hacerlo, hay un "truco" para reducir una ecuación diferencial de segundo orden a dos ecuaciones de primer orden; ¿cuál es?]
#
# (iv) Calcula trayectorias desde distintas condiciones iniciales y dibújalas, y/o ¡hazlo interactivo!
# Debes dibujar tanto $x(t)$ y $y(t)$ como funciones del tiempo, como el **espacio fase** ($y$ contra $x$).

# %% [markdown]
# [4] (i)
# Al igual que antes se tiene
# $$
# \dot{x} \approx\dfrac{x(t+h) - x(t)}{h}\\
# \dot{y} \approx\dfrac{y(t+h) -y(t)}{h}
# $$
# Entonces
# $$
# \dfrac{x(t+h) - x(t)}{h}\approx f(x,y) \Rightarrow x(t+h) \approx hf(x,y)+x(t)\\
# \dfrac{y(t+h) -y(t)}{h}\approx g(x,y) \Rightarrow y(t+h)\approx hg(x,y)+y(t)
# $$
# De manera que hay que resolver estas dos ecuaciones simultaneamente.
# Las relaciones de recurrencia son
# $$
# x_{i+1} = hf(x_i, y_i) + x_i\\
# y_{i+1} = hg(x_i, y_i) + y_i
# $$

# %%
# [4] (ii)
function euler_2_variables(f, g, h, x0, y0, t0)
    ts = t0:h:100
    x = zeros(ts)
    y = zeros(ts)
    x[1] = x0
    y[1] = y0
    for i in 1:length(ts)-1
        x[i+1] = h * f(x[i], y[i]) + x[i]
        y[i+1] = h * g(x[i], y[i]) + y[i]
    end
    return ts, x, y
end
# Out:
# euler_2_variables (generic function with 1 method)

# %% [markdown]
# [4] (iii)
# La ecuación del oscilador armónico amortiguado es
# $$
# \ddot{x} + \dfrac{b}{m}\dot{x} + \dfrac{k}{m}x = 0
# $$
# Bajo el cambio $y = \dot{x}$, se tienen las dos ecuaciones de primer orden
# $$
# \dot{x} = y\\
# \dot{y} = -\dfrac{b}{m}y -\dfrac{k}{m}x
# $$

# %%
k = 1
m = 1
b = 1
f1(x, y) = y
g1(x, y) = ((-b/m) * y) + ((-k/m) * x)
x0 = 30
y0 = 5
h = 0.1
t0 = 0.
t, x, y = euler_2_variables(f1, g1, h, x0, y0, t0)
plot(t, x)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.3701,370.85 39.3701,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.921,370.85 149.921,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   260.472,370.85 260.472,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.024,370.85 371.024,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   481.575,370.85 481.575,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,370.85 592.126,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,316.046 583.835,316.046
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,215.5 583.835,215.5
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,114.955 583.835,114.955
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,14.4095 583.835,14.4095
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 592.126,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.921,376.378 149.921,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   260.472,376.378 260.472,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.024,376.378 371.024,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   481.575,376.378 481.575,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,376.378 592.126,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,316.046 47.6614,316.046
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,215.5 47.6614,215.5
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,114.955 47.6614,114.955
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,14.4095 47.6614,14.4095
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 390.178)" x="39.3701" y="390.178">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.921, 390.178)" x="149.921" y="390.178">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.472, 390.178)" x="260.472" y="390.178">40</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.024, 390.178)" x="371.024" y="390.178">60</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 481.575, 390.178)" x="481.575" y="390.178">80</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 390.178)" x="592.126" y="390.178">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 320.546)" x="33.3701" y="320.546">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 220)" x="33.3701" y="220">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 119.455)" x="33.3701" y="119.455">20</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 18.9095)" x="33.3701" y="18.9095">30</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,14.4095 39.9228,9.3822 40.4756,7.87402 41.0283,9.58329 41.5811,14.2034 42.1339,21.426 42.6866,30.9449 43.2394,42.458 43.7921,55.6709 44.3449,70.2983
#   44.8976,86.0668 45.4504,102.716 46.0031,120 46.5559,137.689 47.1087,155.569 47.6614,173.445 48.2142,191.138 48.7669,208.488 49.3197,225.352 49.8724,241.605
#   50.4252,257.14 50.978,271.866 51.5307,285.708 52.0835,298.607 52.6362,310.521 53.189,321.417 53.7417,331.279 54.2945,340.101 54.8472,347.888 55.4,354.656
#   55.9528,360.429 56.5055,365.239 57.0583,369.123 57.611,372.128 58.1638,374.301 58.7165,375.696 59.2693,376.369 59.822,376.378 60.3748,375.783 60.9276,374.644
#   61.4803,373.022 62.0331,370.976 62.5858,368.565 63.1386,365.845 63.6913,362.873 64.2441,359.699 64.7969,356.375 65.3496,352.946 65.9024,349.458 66.4551,345.949
#   67.0079,342.456 67.5606,339.014 68.1134,335.653 68.6661,332.397 69.2189,329.271 69.7717,326.294 70.3244,323.483 70.8772,320.85 71.4299,318.406 71.9827,316.159
#   72.5354,314.112 73.0882,312.27 73.6409,310.63 74.1937,309.193 74.7465,307.953 75.2992,306.906 75.852,306.045 76.4047,305.361 76.9575,304.845 77.5102,304.488
#   78.063,304.278 78.6157,304.206 79.1685,304.258 79.7213,304.423 80.274,304.69 80.8268,305.046 81.3795,305.48 81.9323,305.981 82.485,306.537 83.0378,307.138
#   83.5906,307.775 84.1433,308.436 84.6961,309.115 85.2488,309.801 85.8016,310.488 86.3543,311.169 8

# %%
for tiempo = 1:2
    scatter([x[tiempo]], [y[tiempo]])
end

# %%
anim = @animate for tiempo = 1:length(t)
    scatter([cosd.(x[tiempo])], [sind.(x[tiempo])], xlims=(-3,5), ylims=(-3,5))
end
gif(anim, "pendulo_amortiguado.gif", fps=15)
# Out:
# INFO: Saved animation to /Users/uzielnmtz/FisicaComputacional2018_1/notebooks/pendulo_amortiguado.gif
# Plots.AnimatedGif("/Users/uzielnmtz/FisicaComputacional2018_1/notebooks/pendulo_amortiguado.gif")

# %% [markdown]
# ## El enfoque vectorial

# %% [markdown]
# Recordemos que *cualquier* EDO, *incluídas las de orden superior* (es decir, con derivadas más altas que la primera de alguna función) se puede escribir en la forma
# $$\dot{\mathbf{x}} = \mathbf{f}(\mathbf{x}, t) \qquad (*)$$
#
# es decir
#
# $$\dot{\mathbf{x}}(t) = \mathbf{f}(\mathbf{x}(t), t),$$
#
# donde ahora $\mathbf{x} = (x_1, \ldots, x_n) \in \mathbb{R}^n$ es un vector y $\mathbf{f}: \mathbb{R}^n \to \mathbb{R}^n$ es una función vectorial, que nos da un **campo vectorial** que indica en cuál dirección seguir desde cada punto del espacio.

# %% [markdown]
# **[5]** (i) Deriva un método de Euler un paso del método de Euler para las ecuaciones acopladas
#
# $$\dot{\mathbf{x}} = \mathbf{f}(\mathbf{x}, t).$$
#
# (ii) Implementa un paso de este método en una función `paso_Euler`. El código debe ser *genérico*, es decir, debe funcionar para cualquier función $\mathbf{f}$ y vector $\mathbf{x}$.
#
# (iii) Implementa el método de Euler completo, utilizando la función `paso_Euler`.
#
# (iv) Utiliza tu función para resolver la caída libre vertical y una caída vertical con fricción lineal en la velocidad. Compara gráficamente con el resultado exacto. Dibuja las resultados con distintos tamaños de fricción en una sola gráfica.
#
# (v) Resuelva numéricamente la caída vertical con fricción cuadrática en la velocidad y compáralo gráficamente con la caída con fricción lineal.

# %% [markdown]
# Procediendo en la misma forma que anteriormente se llega a la aproximación
# $$
# \mathbf{\dot{x}}(t + h) \approx h\mathbf{f}(\mathbf{x}, t) + \mathbf{x}(t)
# $$

# %%
# [5] (ii)
function paso_euler(f, h, t0, x0)
    return h * f(x0, t0) + x0
end
# Out:
# paso_euler (generic function with 1 method)

# %%
# [5] (iii)
function euler_multivariable(f, t0, x0, h=0.01; tmax=100)
    ts = 0:h:tmax
    m_dim = length(x0)
    n_dim = length(ts)
    xs = zeros((m_dim, n_dim))
    xs[:, 1] = x0
    for i in 1:length(ts)-1
        xs[:, i+1] = paso_euler(f, h, ts[i], xs[:, i])
    end
    return ts, xs
end
# Out:
# euler_multivariable (generic function with 3 methods)

# %% [markdown]
# [5] (iV)
# Para la caída libre se tienen las ecuaciones
# $$
# \dot{x_1} = x_2\\
# \dot{x_2} = \dfrac{-g}{m}
# $$

# %%
# [5] (iV)
# Caida libre
grav = 9.8
m = 1
sis1(x, t) = [x[2]; -grav/m]
x0 = [100; 0]
t0 = 0
h = 0.01
t, sols = euler_multivariable(sis1, t0, x0, h, tmax=10)
# Out:
# (0.0:0.01:10.0, [100.0 100.0 … -388.531 -389.51; 0.0 -0.098 … -97.902 -98.0])

# %%
caida_libre(t, v0, y0) = -(9.8/2)t^2 + v0*t + y0
# Out:
# caida_libre (generic function with 1 method)

# %%
exacta = caida_libre.(t, 0, 100)
plot(t, exacta, label="Analítica", xlabel="Tiempo")
plot!(t, sols[1,:], label="Numérica")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,372.441 592.126,372.441 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="366"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.3701,366.972 39.3701,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.921,366.972 149.921,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   260.472,366.972 260.472,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.024,366.972 371.024,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   481.575,366.972 481.575,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,366.972 592.126,13.3425
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,305.48 583.835,305.48
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,231.078 583.835,231.078
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,156.677 583.835,156.677
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,82.2754 583.835,82.2754
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,7.87402 583.835,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 592.126,372.441
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 39.3701,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.921,372.441 149.921,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   260.472,372.441 260.472,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.024,372.441 371.024,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   481.575,372.441 481.575,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,372.441 592.126,366.972
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,372.441 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,305.48 47.6614,305.48
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,231.078 47.6614,231.078
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,156.677 47.6614,156.677
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,82.2754 47.6614,82.2754
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.87402 47.6614,7.87402
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 386.241)" x="39.3701" y="386.241">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.921, 386.241)" x="149.921" y="386.241">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.472, 386.241)" x="260.472" y="386.241">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.024, 386.241)" x="371.024" y="386.241">6</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 481.575, 386.241)" x="481.575" y="386.241">8</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 386.241)" x="592.126" y="386.241">10</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 309.98)" x="33.3701" y="309.98">-300</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 235.578)" x="33.3701" y="235.578">-200</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 161.177)" x="33.3701" y="161.177">-100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 86.7754)" x="33.3701" y="86.7754">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 12.374)" x="33.3701" y="12.374">100</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:16; text-anchor:middle;" transform="rotate(0, 315.748, 397.6)" x="315.748" y="397.6">Tiempo</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,7.87402 39.9228,7.87438 40.4756,7.87547 41.0283,7.8773 41.5811,7.87985 42.1339,7.88313 42.6866,7.88714 43.2394,7.89188 43.7921,7.89735 44.3449,7.90355
#   44.8976,7.91047 45.4504,7.91813 46.0031,7.92651 46.5559,7.93563 47.1087,7.94547 47.6614,7.95604 48.2142,7.96734 48.7669,7.97938 49.3197,7.99214 49.8724,8.00562
#   50.4252,8.01984 50.978,8.03479 51.5307,8.05047 52.0835,8.06687 52.6362,8.08401 53.189,8.10187 53.7417,8.12046 54.2945,8.13979 54.8472,8.15984 55.4,8.18062
#   55.9528,8.20213 56.5055,8.22436 57.0583,8.24733 57.611,8.27103 58.1638,8.29546 58.7

# %% [markdown]
# Para la caída con resistencia lineal en la velocidad, las ecuaciones son
# $$
# \dot{x_1} = x_2\\
# \dot{x_2} = -\dfrac{g}{m} + \dfrac{\alpha}{m}x_2
# $$

# %%
m = 1
grav = 9.8
α = 5
sis_res(x, t) = [x[2]; -(grav/m) + (α/m)*x[2]]
x0 = [1000; 10]
t0 = 0
t, sols = euler_multivariable(sis_res, t0, x0, tmax=5)
# Out:
# (0.0:0.01:5.0, [1000.0 1000.1 … 6.02208e10 6.32318e10; 10.0 10.402 … 3.01104e11 3.16159e11])

# %%
plot(t, sols[1, :])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip00)" points="
# 39.3701,376.378 592.126,376.378 592.126,7.87402 39.3701,7.87402
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="39" y="7" width="554" height="370"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.3701,370.85 39.3701,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   149.921,370.85 149.921,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   260.472,370.85 260.472,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   371.024,370.85 371.024,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   481.575,370.85 481.575,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   592.126,370.85 592.126,13.4016
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,259.821 583.835,259.821
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,143.265 583.835,143.265
#   "/>
# <polyline clip-path="url(#clip02)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   47.6614,26.7084 583.835,26.7084
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 592.126,376.378
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   149.921,376.378 149.921,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   260.472,376.378 260.472,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   371.024,376.378 371.024,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   481.575,376.378 481.575,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   592.126,376.378 592.126,370.85
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 39.3701,7.87402
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,259.821 47.6614,259.821
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,143.265 47.6614,143.265
#   "/>
# <polyline clip-path="url(#clip00)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,26.7084 47.6614,26.7084
#   "/>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 39.3701, 390.178)" x="39.3701" y="390.178">0</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 149.921, 390.178)" x="149.921" y="390.178">1</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 260.472, 390.178)" x="260.472" y="390.178">2</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 371.024, 390.178)" x="371.024" y="390.178">3</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 481.575, 390.178)" x="481.575" y="390.178">4</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 592.126, 390.178)" x="592.126" y="390.178">5</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 264.321)" x="33.3701" y="264.321">20000000000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 147.765)" x="33.3701" y="147.765">40000000000</text>
# </g>
# <g clip-path="url(#clip00)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 33.3701, 31.2084)" x="33.3701" y="31.2084">60000000000</text>
# </g>
# <polyline clip-path="url(#clip02)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.3701,376.378 40.4756,376.378 41.5811,376.378 42.6866,376.378 43.7921,376.378 44.8976,376.378 46.0031,376.378 47.1087,376.378 48.2142,376.378 49.3197,376.378
#   50.4252,376.378 51.5307,376.378 52.6362,376.378 53.7417,376.378 54.8472,376.378 55.9528,376.378 57.0583,376.378 58.1638,376.378 59.2693,376.378 60.3748,376.378
#   61.4803,376.378 62.5858,376.378 63.6913,376.378 64.7969,376.378 65.9024,376.378 67.0079,376.378 68.1134,376.378 69.2189,376.378 70.3244,376.378 71.4299,376.378
#   72.5354,376.378 73.6409,376.378 74.7465,376.378 75.852,376.378 76.9575,376.378 78.063,376.378 79.1685,376.378 80.274,376.378 81.3795,376.378 82.485,376.378
#   83.5906,376.378 84.6961,376.378 85.8016,376.378 86.9071,376.378 88.0126,376.378 89.1181,376.378 90.2236,376.378 91.3291,376.378 92.4346,376.378 93.5402,376.378
#   94.6457,376.378 95.7512,376.378 96.8567,376.378 97.9622,376.378 99.0677,376.378 100.173,376.378 101.279,376.378 102.384,376.378 103.49,376.378 104.595,376.378
#   105.701,376.378 106.806,376.378 107.912,376.378 109.017,376.378 110.123,376.378 111.228,376.378 112.334,376.378 113.439,376.378 114.545,376.378 115.65,376.378
#   116.756,376.378 117.861,376.378 118.967,376.378 120.072,376.378 121.178,376.378 122.283,376.378 123.389,376.378 124.494,376.378 125.6,376.378 126.706,376.378
#   127.811,376.378 128.917,376.378 130.022,376.378 131.128,376.378 132.233,376.378 133.339,376.378 134.444,376.378 135.55,376.378 136.655,376.378 137.761,376.378
#   138.866,376.378 139.972,376.378 141.077,376.378 142.183,376.378 143.288,376.378 144.394,376.378 145.499,376.378 146.605,376.378 147.71,376.378 148.816,376.378
#   149.921,376.378 151.027,376.378 152.132,376.378 153.238,376.378 154.343,376.378 155.449,376.378 156.554,376.378 157.66,376.378 158.765,376.378 159.871,376.378
#   160.976,376.378 162.082,376.378 163.187,376.378 164.293,376.378 165.398,376.378 166.504,376.378 167.609,3

# %% [markdown]
# **[6]** (i) Resuelva numéricamente el problema del tiro parabólico con Euler para un proyectil que empieza en una altura $h>0$ con rapidez $1$ y ángulo inicial $\alpha$, *hasta que* caiga al suelo.
#
# (ii) Encuentra la distancia horizontal donde cae al suelo (el rango). Dibuja el resultado tal que puedas manipular interactivamente las condiciones iniciales. Encuentra numéricamente el ángulo que maximiza el rango. ¿Es correcto?
#
# (iii) Agrega fricción del aire al problema y agrégalo como otro parámetro que puedas manipular. ¿Cómo cambia el resultado de la pregunta (ii)?
